# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulrafay57408/Randon-Forest-Iris-Dataset/blob/main/Random_forest_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
data = pd.read_csv("/content/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data['Target'] = data['Species'].map({'Iris-setosa':0 , 'Iris-versicolor':1, 'Iris-virginica':2 })
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Target
# 0       Iris-setosa       0
# 1       Iris-setosa       0
# 2       Iris-setosa       0
# 3       Iris-setosa       0
# ...

# %%
x = data[['SepalLengthCm', 'SepalWidthCm'  , 'PetalLengthCm' , 'PetalWidthCm']]
y = data['Target']

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Target, Length: 150, dtype: int64

# %%
xTrain , xTest , yTrain, yTest = train_test_split(x , y , test_size=0.2 , random_state=45)

# %%
model = RandomForestClassifier(n_estimators=110 , max_depth= None , random_state=45 )

model.fit(xTrain , yTrain)
# Out:
# RandomForestClassifier(n_estimators=110, random_state=45)

# %%
prediction = model.predict(xTest)

# %%
yTest
# Out:
# 0      0
# 43     0
# 129    2
# 3      0
# 34     0
# 44     0
# 38     0
# 105    2
# 123    2
# 140    2
# 28     0
# 125    2
# 113    2
# 103    2
# 133    2
# 35     0
# 145    2
# 142    2
# 40     0
# 87     1
# 84     1
# 85     1
# 115    2
# 51     1
# 4      0
# 112    2
# 92     1
# 64     1
# 10     0
# 91     1
# Name: Target, dtype: int64

# %%
prediction
# Out:
# array([0, 0, 1, 0, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2, 2, 0, 1, 1, 1,
#        2, 1, 0, 2, 1, 1, 0, 1])

# %%
accuracy = accuracy_score(yTest , prediction)
accuracy
# Out:
# 0.9333333333333333

# %%
confusion = confusion_matrix(yTest , prediction)
confusion
# Out:
# array([[11,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  2, 10]])

# %%
sns.heatmap(confusion_matrix(yTest , prediction) ,annot=True, cmap='coolwarm')
plt.title("Confusion Matrix")
plt.show()

# %%
tuned = RandomForestClassifier(n_estimators=50, max_depth=5, random_state=42)
tuned.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)

# %%
tunedPrediction = tuned.predict(xTest)
tunedPrediction
# Out:
# array([0, 0, 1, 0, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2, 2, 0, 1, 1, 1,
#        2, 1, 0, 2, 1, 1, 0, 1])

# %%
tunedAccuracy = accuracy_score(yTest, tunedPrediction)
tunedAccuracy
# Out:
# 0.9333333333333333

# %%
confusion_matrix(yTest, tunedPrediction)
# Out:
# array([[11,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  2, 10]])

# %%
sns.heatmap(confusion_matrix(yTest, tunedPrediction) ,annot=True, cmap='coolwarm')
plt.title("Confusion Matrix After Adjusting Hyperparameters")
plt.show()

# %% [markdown]
# 1.   **Random Forest** is a machine learning algorithm which works multiple decision trees to classify data into different categories and predicts based on maximum votes.
# 2.   **Advantages:**
#
# *   It prevents from the overfitting as compared to other decisions tree.
# *   It works on both Regression and Classifier data
# *   It can handle some missing data and work properly even if some data is missing.
# *   It is more accurate , especially in large dataset.

# %% [markdown]
# # **Deliverable**

# %% [markdown]
# ###**Accuracy**

# %%
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.9333333333333333

# %% [markdown]
# ### **Confusion Matrix**

# %%
print(f"Confusion Matrix: \n{confusion}")
# Out:
# Confusion Matrix:
# [[11  0  0]
#  [ 0  7  0]
#  [ 0  2 10]]

# %% [markdown]
# ### **Observation**
#
#
# *   Random Forest perform well on iris dataset due to its simplicity.
# *   Reducing the number of trees and limiting the depth is not impacting on it performance in this case.
